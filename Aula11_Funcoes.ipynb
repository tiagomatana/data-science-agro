# %% [markdown]
# # <font color="red"> Data Science no Agronegócio</font>
# ## <span style="color:red">Linguagens e Ferramentas para *Data Science* no Agronegócio</span>
#
# ### <span style="color:darkred">Python: Funções</span>
#
# *Dr. Guilherme Martineli Sanches*<br>
# *Cropman*

# %% [markdown]
# ---
#
# ## Codificando Funções
#
# Existem diversas funções nativas do Python, que foram implementadas para facilitar nossa vida:
#
# * `len()`
# * `sum()`
# * `type()`
# * `input()`
#
# Funções são úteis quando temos que repetir uma tarefa várias vezes.
#
# Podemos programar nossa própria função, usando a seguinte sintaxe:
#
# ```
# def <identificador_da_funcao>(<uma ou mais variaveis parametros da funcao>):
#     <codigo indentado parte da funcao>
#     <return : caso essa funcao retorne algo>
# ```
#
# em outras palavras....
#
# ```
# def nome_funcao():
#     faça alguma coisa
#     faça outra coisa
#     return valor_final
# ```
#
# A palavra `def` indica a definição da função, que passará a ficar disponível para uso.
#
# Vamos criar uma função que receba um número e verifique se esse número é `int` ou `float` o que pode ser útil para controle de entrada

# %%
def minhafuncao(x):
    if (type(x) == int or type(x) == float):
        print("é inteiro ou float")
    else:
        print("não é inteiro nem float")

# %%
val1 = 'data'
minhafuncao(val1)

# val2 = 3
# is_intfloat(val2)

# val3 = 'agro'
# is_intfloat(val3)
# Out:
# não é inteiro nem float

# %% [markdown]
# A nossa função *imprime* o resultado na tela, mas **não é recomendado** que funções possuam operações de *entrada e saída*.
#
# É muito mais útil que a função devolva o resultado de alguma forma. Isso é feito pelo comando `return`
#
# > Esse é um erro comum: usar `print()` ao invés de return.

# %%
def is_intfloat(x):
    if (type(x) == int or type(x) == float):
        return True
    else:
        return False
    
val1 = 3.0
print(is_intfloat(val1))

val3 = 'agro'
print(is_intfloat(val3))
# Out:
# agro
# False

# %% [markdown]
# Podemos criar também uma função com mais de um parâmetro
#
#
# def minha_funcao(parametro1, parametro2, parametro3):
# > return parametro1 + parametro2 + parametro3

# %%
def soma(num1, num2, num3):
    return num1 * num2 + num3


test = soma(10, 20, 0)
print(test)
# Out:
# 200

# %% [markdown]
# ---
#
# **<font color="blue">Exercício 6</font>**
#
# - Vamos criar uma function com parâmetro
#
# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora.
#
# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.
#
# Ex:<br>
# KCl -> BEB12302<br>
# Ureia -> BEB12043<br>
# Formulado 10-10-10 -> BEB34501<br>
#
# Vaso -> BSA11104<br>
# Cadeira -> BSA54301<br>
# Cloro -> BSA34012<br>
# Enxada -> BSA09871<br>
#
# Repare que adubos começam com BEB, enquanto produtos variados começam com BSA.
#
# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de adubos.

# %%
produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']
